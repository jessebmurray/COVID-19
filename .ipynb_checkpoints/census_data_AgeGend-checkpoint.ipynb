# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

pd.options.display.max_columns = 1000
plt.style.use('default')

# %% [markdown]
# ### Read 2018 demographic data

# %%
dfc = pd.read_csv('../files/census/cc-est2018-alldata.csv', encoding='ISO-8859-1')

# %%
dfc.YEAR.unique()[-1]
# Out:
# 11

# %%
# Get 2010 data
dfc = dfc.loc[dfc.YEAR == dfc.YEAR.unique()[-1]]

# %%
start_race_idx = dfc.columns.tolist().index('WA_MALE')

# %%
race_cols = dfc.columns[start_race_idx:]

# %%
# COMBINE MALE AND FEMALE RACE COLUMNS
for col in race_cols:
    if col[-6:] == 'FEMALE':
        identifier = col[:-7]
        col_male = identifier + '_MALE'
        dfc[identifier] = dfc[identifier + '_FEMALE'] + dfc[identifier + '_MALE']

# %%
dfc.drop(columns=race_cols, inplace=True)

# %%
dfc['TOT_MALE'] /= dfc['TOT_POP']

# %%
test = pd.DataFrame(dfc.groupby(['STATE', 'COUNTY', 'AGEGRP', 
                                 'TOT_MALE']).TOT_POP.sum()).reset_index()

# %%
test = pd.pivot_table(test, index=['STATE', 'COUNTY'],
               values=['TOT_POP', 'TOT_MALE'], columns='AGEGRP').reset_index(drop=True)

# %%
dfc = dfc.loc[dfc.AGEGRP == 0]

dfc = dfc.reset_index(drop=True)

# %%
test.columns = test.columns.to_flat_index()

test.columns = ['_'.join([str(value) for value in tup]) for tup in test.columns]

# %%
gen_rename = {1:'zero_four', 2:'five_nine', 3:'ten_fourteen', 4:'fifteen_nineteen',
                   5:'twenty_twentyfour', 6:'twentyfive_twentynine', 7:'thirty_thirtyfour',
                   8:'thirtyfive_thirtynine', 9:'forty_fortyfour', 10:'fortyfive_fortynine',
                   11:'fifty_fiftyfour', 12:'fiftyfive_fiftynine', 13:'sixty_sixtyfour',
                   14:'sixtyfive_sixtynine', 15:'seventy_seventyfour', 
                    16:'seventyfive_seventynine', 17:'eighty_eightyfour', 18:'eightyfive_older'}

# %%
rename_dict = dict()
for i in range(len(test.columns)):
    column = test.columns[i]
    if len(column) == 10:
#         print(column)
        if column[:-2] == 'TOT_MALE':
            column_int = int(column[-1])
            if column_int == 0:
                rename_dict[column] = column[:-2]
            else:
                rename_dict[column] = column[:-1] + gen_rename[column_int]
        else:
            rename_dict[column] = column[:-2] + gen_rename[int(column[-2:])]
    else:
        if len(column) == 11:
            rename_dict[column] = column[:-2] + gen_rename[int(column[-2:])]
#         else:
#             print(column[-1:])
        else:
            column_int = int(column[-1])
            if column_int == 0:
                rename_dict[column] = column[:-2]
            else:
                rename_dict[column] = column[:-1] + gen_rename[column_int]

# %%
test = test.rename(columns=rename_dict)

# %%
test
# Out:
#       TOT_MALE  TOT_MALE_zero_four  TOT_MALE_five_nine  TOT_MALE_ten_fourteen  \
# 0     0.485513            0.513674            0.519720               0.509274
# 1     0.484616            0.513174            0.509217               0.504184
# 2     0.527832            0.510903            0.495166               0.513585
# 3     0.532188            0.510506            0.520922               0.536199
# 4     0.492739            0.497977            0.505640               0.492824
# ...        ...                 ...                 ...                    ...
# 3137  0.514553            0.522550            0.513154               0.502567
# 3138  0.515966            0.522085            0.480032               0.533278
# 3139  0.506675            0.511440            0.517431               0.502576
# 3140  0.505770            0.539409            0.486726               0.500000
# 3141  0.529496            0.515320            0.486936               0.533019
#
#       TOT_MALE_fifteen_nineteen  TOT_MALE_twenty_twentyfour  \
# 0                      0.509454                    0.513394
# 1                      0.494742                    0.507022
# 2                      0.523088                    0.591712
# 3                      0.537795                    0.588642
# 4                      0.513086                    0.528634
# ...                         ...                         ...
# 3137                   0.513433                    0.522359
# 3138                   0.509664                    0.431354
# 3139                   0.548011                    0.501502
# 3140                   0.538879                    0.502841
# 3141                   0.543662                    0.615385
#
#       TOT_MALE_twentyfive_twentynine  TOT_MALE_thirty_thirtyfour  \
# 0                           0.493927                    0.479341
# 1                           0.492743                    0.492743
# 2                           0.630846                    0.594012
# 3                           0.575898                    0.599625
# 4                           0.502525                    0.500593
# ...                              ...                         ...
# 3137                        0.515537                    0.508618
# 3138                        0.535204                    0.523176
# 3139                        0.485269                    0.496779
# 3140                        0.504132                    0.552885
# 3141                        0.571816                    0.544186
#
#       TOT_MALE_thirtyfive_thirtynine  TOT_MALE_forty_fortyfour  \
# 0                           0.487045                  0.474834
# 1                           0.480237                  0.486216
# 2                           0.602874                  0.597931
# 3                           0.603175                  0.552778
# 4                           0.505122                  0.489446
# ...                              ...                       ...
# 3137                        0.516243                  0.524665
# 3138                        0.544794                  0.552995
# 3139                        0.506164                  0.500795
# 3140                        0.476386                  0.500000
# 3141                        0.544118                  0.561644
#
#       TOT_MALE_fortyfive_fortynine  TOT_MALE_fifty_fiftyfour  \
# 0                         0.482098                  0.484125
# 1                         0.486688                  0.478655
# 2                         0.572044                  0.528384
# 3                         0.554443                  0.535737
# 4                         0.502168                  0.493457
# ...                            ...                       ...
# 3137                      0.520833                  0.521411
# 3138                      0.547125                  0.491216
# 3139                      0.509717                  0.511236
# 3140                      0.528261                  0.523166
# 3141                      0.579946                  0.526196
#
#       TOT_MALE_fiftyfive_fiftynine  TOT_MALE_sixty_sixtyfour  \
# 0                         0.498090                  0.462156
# 1                         0.471037                  0.466454
# 2                         0.493134                  0.487630
# 3                         0.522164                  0.492296
# 4                         0.515328                  0.484659
# ...                            ...                       ...
# 3137                      0.523098                  0.537552
# 3138                      0.494352                  0.512638
# 3139                      0.505857                  0.504178
# 3140                      0.490300                  0.514143
# 3141                      0.535649                  0.513393
#
#       TOT_MALE_sixtyfive_sixtynine  TOT_MALE_seventy_seventyfour  \
# 0                         0.474314                      0.440935
# 1                         0.464148                      0.479031
# 2                         0.455195                      0.454749
# 3                         0.487310                      0.458669
# 4                         0.476539                      0.448835
# ...                            ...                           ...
# 3137                      0.513304                      0.504029
# 3138                      0.537538                      0.508647
# 3139                      0.519678                      0.519582
# 3140                      0.518375                      0.485714
# 3141                      0.564482                      0.500000
#
#       TOT_MALE_seventyfive_seventynine  TOT_MALE_eighty_eightyfour  \
# 0                             0.416331                    0.426072
# 1                             0.466155                    0.470774
# 3141                    439.0                        547.0
#
#       TOT_POP_sixty_sixtyfour  TOT_POP_sixtyfive_sixtynine  \
# 0                      3237.0                       2589.0
# 1                     15665.0                      14267.0
# 2                      1536.0                       1540.0
# 3                      1363.0                       1182.0
# 4                      3683.0                       3282.0
# ...                       ...                          ...
# 3137                   2876.0                       2067.0
# 3138                   1543.0                       1332.0
# 3139                   1436.0                       1118.0
# 3140                    601.0                        517.0
# 3141                    672.0                        473.0
#
#       TOT_POP_seventy_seventyfour  TOT_POP_seventyfive_seventynine  \
# 0                          2311.0                           1739.0
# 1                         12471.0                           8465.0
# 2                          1337.0                            907.0
# 3                           992.0                            731.0
# 4                          2961.0                           1970.0
# ...                           ...                              ...
# 3137                       1365.0                            833.0
# 3138                        983.0                            586.0
# 3139                        766.0                            467.0
# 3140                        420.0                            321.0
# 3141                        336.0                            224.0
#
#       TOT_POP_eighty_eightyfour  TOT_POP_eightyfive_older
# 0                        1143.0                     871.0
# 1                        5064.0                    4304.0
# 2                         576.0                     472.0
# 3                         422.0                     363.0
# 4                        1303.0                    1032.0
# ...                         ...                       ...
# 3137                      478.0                     471.0
# 3138                      332.0                     325.0
# 3139                      252.0                     255.0
# 3140                      210.0                     242.0
# 3141                      196.0                     200.0
#
# [3142 rows x 38 columns]

# %%
test2 = test[test.columns[1:19:1]].melt()
plt.title('Average percentage of men in each age group for each US County')
sns.barplot(x='variable', y='value', data=test2)
plt.xticks(np.arange(0, 18), [str(num) for num in np.arange(0, 90, 5)])
plt.show()

# %%
test
# Out:
#       TOT_MALE  TOT_MALE_zero_four  TOT_MALE_five_nine  TOT_MALE_ten_fourteen  \
# 0     0.485513            0.513674            0.519720               0.509274
# 1     0.484616            0.513174            0.509217               0.504184
# 2     0.527832            0.510903            0.495166               0.513585
# 3     0.532188            0.510506            0.520922               0.536199
# 4     0.492739            0.497977            0.505640               0.492824
# ...        ...                 ...                 ...                    ...
# 3137  0.514553            0.522550            0.513154               0.502567
# 3138  0.515966            0.522085            0.480032               0.533278
# 3139  0.506675            0.511440            0.517431               0.502576
# 3140  0.505770            0.539409            0.486726               0.500000
# 3141  0.529496            0.515320            0.486936               0.533019
#
#       TOT_MALE_fifteen_nineteen  TOT_MALE_twenty_twentyfour  \
# 0                      0.509454                    0.513394
# 1                      0.494742                    0.507022
# 2                      0.523088                    0.591712
# 3                      0.537795                    0.588642
# 4                      0.513086                    0.528634
# ...                         ...                         ...
# 3137                   0.513433                    0.522359
# 3138                   0.509664                    0.431354
# 3139                   0.548011                    0.501502
# 3140                   0.538879                    0.502841
# 3141                   0.543662                    0.615385
#
#       TOT_MALE_twentyfive_twentynine  TOT_MALE_thirty_thirtyfour  \
# 0                           0.493927                    0.479341
# 1                           0.492743                    0.492743
# 2                           0.630846                    0.594012
# 3                           0.575898                    0.599625
# 4                           0.502525                    0.500593
# ...                              ...                         ...
# 3137                        0.515537                    0.508618
# 3138                        0.535204                    0.523176
# 3139                        0.485269                    0.496779
# 3140                        0.504132                    0.552885
# 3141                        0.571816                    0.544186
#
#       TOT_MALE_thirtyfive_thirtynine  TOT_MALE_forty_fortyfour  \
# 0                           0.487045                  0.474834
# 1                           0.480237                  0.486216
# 2                           0.602874                  0.597931
# 3                           0.603175                  0.552778
# 4                           0.505122                  0.489446
# ...                              ...                       ...
# 3137                        0.516243                  0.524665
# 3138                        0.544794                  0.552995
# 3139                        0.506164                  0.500795
# 3140                        0.476386                  0.500000
# 3141                        0.544118                  0.561644
#
#       TOT_MALE_fortyfive_fortynine  TOT_MALE_fifty_fiftyfour  \
# 0                         0.482098                  0.484125
# 1                         0.486688                  0.478655
# 2                         0.572044                  0.528384
# 3                         0.554443                  0.535737
# 4                         0.502168                  0.493457
# ...                            ...                       ...
# 3137                      0.520833                  0.521411
# 3138                      0.547125                  0.491216
# 3139                      0.509717                  0.511236
# 3140                      0.528261                  0.523166
# 3141                      0.579946                  0.526196
#
#       TOT_MALE_fiftyfive_fiftynine  TOT_MALE_sixty_sixtyfour  \
# 0                         0.498090                  0.462156
# 1                         0.471037                  0.466454
# 2                         0.493134                  0.487630
# 3                         0.522164                  0.492296
# 4                         0.515328                  0.484659
# ...                            ...                       ...
# 3137                      0.523098                  0.537552
# 3138                      0.494352                  0.512638
# 3139                      0.505857                  0.504178
# 3140                      0.490300                  0.514143
# 3141                      0.535649                  0.513393
#
#       TOT_MALE_sixtyfive_sixtynine  TOT_MALE_seventy_seventyfour  \
# 0                         0.474314                      0.440935
# 1                         0.464148                      0.479031
# 2                         0.455195                      0.454749
# 3                         0.487310                      0.458669
# 4                         0.476539                      0.448835
# ...                            ...                           ...
# 3137                      0.513304                      0.504029
# 3138                      0.537538                      0.508647
# 3139                      0.519678                      0.519582
# 3140                      0.518375                      0.485714
# 3141                      0.564482                      0.500000
#
#       TOT_MALE_seventyfive_seventynine  TOT_MALE_eighty_eightyfour  \
# 0                             0.416331                    0.426072
# 1                             0.466155                    0.470774
# 2                             0.442117                    0.401042
# 3                             0.441860                    0.390995
# 4                             0.456345                    0.451266
# ...                                ...                         ...
# 3137                          0.507803                    0.447699
# 3138                          0.501706                    0.463855
# 3139                          0.503212                    0.452381
# 3140                          0.545171                    0.400000
# 3141                          0.464286                    0.448980
#
#       TOT_MALE_eightyfive_older   TOT_POP  TOT_POP_zero_four  \
# 0                      0.377727   55601.0             3364.0
# 1                      0.407760  218022.0            11955.0
# 2                      0.313559   24881.0             1284.0
# 3                      0.297521   22400.0             1285.0
# 4                      0.359496   57840.0             3460.0
# ...                         ...       ...                ...
# 3137                   0.339703   43051.0             2949.0
# 3138                   0.406154   23081.0             1132.0
# 3139                   0.349020   20299.0             1486.0
# 3140                   0.400826    7885.0              406.0
# 3141                   0.345000    6967.0              359.0
#
#       TOT_POP_five_nine  TOT_POP_ten_fourteen  TOT_POP_fifteen_nineteen  \
# 0                3423.0                3882.0                    3755.0
# 1               12802.0               13981.0                   12932.0
# 2                1448.0                1509.0                    1451.0
# 3                         422.0                     363.0
# 4                        1303.0                    1032.0
# ...                         ...                       ...
# 3137                      478.0                     471.0
# 3138                      332.0                     325.0
# 3139                      252.0                     255.0
# 3140                      210.0                     242.0
# 3141                      196.0                     200.0
#
# [3142 rows x 38 columns]

# %%
(test.TOT_POP == dfc.TOT_POP).unique()
# Out:
# array([ True])

# %%
test.drop(columns=['TOT_POP', 'TOT_MALE'], inplace=True)

# %%
test
# Out:
#       TOT_MALE_zero_four  TOT_MALE_five_nine  TOT_MALE_ten_fourteen  \
# 0               0.513674            0.519720               0.509274
# 1               0.513174            0.509217               0.504184
# 2               0.510903            0.495166               0.513585
# 3               0.510506            0.520922               0.536199
# 4               0.497977            0.505640               0.492824
# ...                  ...                 ...                    ...
# 3137            0.522550            0.513154               0.502567
# 3138            0.522085            0.480032               0.533278
# 3139            0.511440            0.517431               0.502576
# 3140            0.539409            0.486726               0.500000
# 3141            0.515320            0.486936               0.533019
#
#       TOT_MALE_fifteen_nineteen  TOT_MALE_twenty_twentyfour  \
# 0                      0.509454                    0.513394
# 1                      0.494742                    0.507022
# 2                      0.523088                    0.591712
# 3                      0.537795                    0.588642
# 4                      0.513086                    0.528634
# ...                         ...                         ...
# 3137                   0.513433                    0.522359
# 3138                   0.509664                    0.431354
# 3139                   0.548011                    0.501502
# 3140                   0.538879                    0.502841
# 3141                   0.543662                    0.615385
#
#       TOT_MALE_twentyfive_twentynine  TOT_MALE_thirty_thirtyfour  \
# 0                           0.493927                    0.479341
# 1                           0.492743                    0.492743
# 2                           0.630846                    0.594012
# 3                           0.575898                    0.599625
# 4                           0.502525                    0.500593
# ...                              ...                         ...
# 3137                        0.515537                    0.508618
# 3138                        0.535204                    0.523176
# 3139                        0.485269                    0.496779
# 3140                        0.504132                    0.552885
# 3141                        0.571816                    0.544186
#
#       TOT_MALE_thirtyfive_thirtynine  TOT_MALE_forty_fortyfour  \
# 0                           0.487045                  0.474834
# 1                           0.480237                  0.486216
# 2                           0.602874                  0.597931
# 3                           0.603175                  0.552778
# 4                           0.505122                  0.489446
# ...                              ...                       ...
# 3137                        0.516243                  0.524665
# 3138                        0.544794                  0.552995
# 3139                        0.506164                  0.500795
# 3140                        0.476386                  0.500000
# 3141                        0.544118                  0.561644
#
#       TOT_MALE_fortyfive_fortynine  TOT_MALE_fifty_fiftyfour  \
# 0                         0.482098                  0.484125
# 1                         0.486688                  0.478655
# 2                         0.572044                  0.528384
# 3                         0.554443                  0.535737
# 4                         0.502168                  0.493457
# ...                            ...                       ...
# 3137                      0.520833                  0.521411
# 3138                      0.547125                  0.491216
# 3139                      0.509717                  0.511236
# 3140                      0.528261                  0.523166
# 3141                      0.579946                  0.526196
#
#       TOT_MALE_fiftyfive_fiftynine  TOT_MALE_sixty_sixtyfour  \
# 0                         0.498090                  0.462156
# 1                         0.471037                  0.466454
# 2                         0.493134                  0.487630
# 3                         0.522164                  0.492296
# 4                         0.515328                  0.484659
# ...                            ...                       ...
# 3137                      0.523098                  0.537552
# 4                      3553.0                       3921.0
# ...                       ...                          ...
# 3137                   2838.0                       2496.0
# 3138                   1736.0                       1687.0
# 3139                   1258.0                       1132.0
# 3140                    440.0                        460.0
# 3141                    365.0                        369.0
#
#       TOT_POP_fifty_fiftyfour  TOT_POP_fiftyfive_fiftynine  \
# 0                      3811.0                       3927.0
# 1                     14242.0                      15744.0
# 2                      1603.0                       1675.0
# 3                      1581.0                       1534.0
# 4                      3897.0                       3947.0
# ...                       ...                          ...
# 3137                   2382.0                       2879.0
# 3138                   1423.0                       1505.0
# 3139                   1068.0                       1366.0
# 3140                    518.0                        567.0
# 3141                    439.0                        547.0
#
#       TOT_POP_sixty_sixtyfour  TOT_POP_sixtyfive_sixtynine  \
# 0                      3237.0                       2589.0
# 1                     15665.0                      14267.0
# 2                      1536.0                       1540.0
# 3                      1363.0                       1182.0
# 4                      3683.0                       3282.0
# ...                       ...                          ...
# 3137                   2876.0                       2067.0
# 3138                   1543.0                       1332.0
# 3139                   1436.0                       1118.0
# 3140                    601.0                        517.0
# 3141                    672.0                        473.0
#
#       TOT_POP_seventy_seventyfour  TOT_POP_seventyfive_seventynine  \
# 0                          2311.0                           1739.0
# 1                         12471.0                           8465.0
# 2                          1337.0                            907.0
# 3                           992.0                            731.0
# 4                          2961.0                           1970.0
# ...                           ...                              ...
# 3137                       1365.0                            833.0
# 3138                        983.0                            586.0
# 3139                        766.0                            467.0
# 3140                        420.0                            321.0
# 3141                        336.0                            224.0
#
#       TOT_POP_eighty_eightyfour  TOT_POP_eightyfive_older
# 0                        1143.0                     871.0
# 1                        5064.0                    4304.0
# 2                         576.0                     472.0
# 3                         422.0                     363.0
# 4                        1303.0                    1032.0
# ...                         ...                       ...
# 3137                      478.0                     471.0
# 3138                      332.0                     325.0
# 3139                      252.0                     255.0
# 3140                      210.0                     242.0
# 3141                      196.0                     200.0
#
# [3142 rows x 36 columns]

# %%
dfc = pd.concat([dfc, test], axis=1)

# %%
# # GET AGE BRACKETS FOR TOTAL POPULATION, USE TOTAL FOR ALL OTHER DEMOGRAPHICS
# dfage = pd.DataFrame(dfc.groupby(['STATE', 'COUNTY', 'AGEGRP']).TOT_POP.sum()).reset_index()

# dfage = pd.pivot_table(dfage, index=['STATE', 'COUNTY'],
#                values='TOT_POP', columns='AGEGRP').reset_index(drop=True)

# dfc = dfc.loc[dfc.AGEGRP == 0]

# dfc = dfc.reset_index(drop=True)

# dfage.rename(columns={0:'total'}, inplace=True)

# (dfage.total == dfc.TOT_POP).unique()

# %%
# dfc = pd.concat([dfc, dfage], axis=1)

# %%
dfc = dfc.drop(columns=['SUMLEV'])

# %%
dfc = dfc.drop(columns=['AGEGRP', 'YEAR'])

# %%
dfc.columns[5:]
# Out:
# Index(['TOT_MALE', 'TOT_FEMALE', 'WA', 'BA', 'IA', 'AA', 'NA', 'TOM', 'WAC',
#        'BAC', 'IAC', 'AAC', 'NAC', 'NH', 'NHWA', 'NHBA', 'NHIA', 'NHAA',
#        'NHNA', 'NHTOM', 'NHWAC', 'NHBAC', 'NHIAC', 'NHAAC', 'NHNAC', 'H',
#        'HWA', 'HBA', 'HIA', 'HAA', 'HNA', 'HTOM', 'HWAC', 'HBAC', 'HIAC',
#        'HAAC', 'HNAC', 'TOT_MALE_zero_four', 'TOT_MALE_five_nine',
#        'TOT_MALE_ten_fourteen', 'TOT_MALE_fifteen_nineteen',
#        'TOT_MALE_twenty_twentyfour', 'TOT_MALE_twentyfive_twentynine',
#        'TOT_MALE_thirty_thirtyfour', 'TOT_MALE_thirtyfive_thirtynine',
#        'TOT_MALE_forty_fortyfour', 'TOT_MALE_fortyfive_fortynine',
#        'TOT_MALE_fifty_fiftyfour', 'TOT_MALE_fiftyfive_fiftynine',
#        'TOT_MALE_sixty_sixtyfour', 'TOT_MALE_sixtyfive_sixtynine',
#        'TOT_MALE_seventy_seventyfour', 'TOT_MALE_seventyfive_seventynine',
#        'TOT_MALE_eighty_eightyfour', 'TOT_MALE_eightyfive_older',
#        'TOT_POP_zero_four', 'TOT_POP_five_nine', 'TOT_POP_ten_fourteen',
#        'TOT_POP_fifteen_nineteen', 'TOT_POP_twenty_twentyfour',
#        'TOT_POP_twentyfive_twentynine', 'TOT_POP_thirty_thirtyfour',
#        'TOT_POP_thirtyfive_thirtynine', 'TOT_POP_forty_fortyfour',
#        'TOT_POP_fortyfive_fortynine', 'TOT_POP_fifty_fiftyfour',
#        'TOT_POP_fiftyfive_fiftynine', 'TOT_POP_sixty_sixtyfour',
#        'TOT_POP_sixtyfive_sixtynine', 'TOT_POP_seventy_seventyfour',
#        'TOT_POP_seventyfive_seventynine', 'TOT_POP_eighty_eightyfour',
#        'TOT_POP_eightyfive_older'],
#       dtype='object')

# %%
low_idx = dfc.columns.tolist().index('TOT_MALE_zero_four')
high_idx = dfc.columns.tolist().index('TOT_MALE_eightyfive_older')

# %%
# NORMALIZE FEATURES TO POPULATION SIZE
dont_norm = dfc.columns[low_idx:high_idx + 1].tolist()

for column in dfc.columns[5:]:
    if column not in dont_norm:
        dfc[column] /= dfc.TOT_POP

# %%
dfc['FIPS'] = dfc.STATE.map(lambda x: '{:02d}'.format(x)) + dfc.COUNTY.map(lambda x: 
                                                                        '{:03d}'.format(x))

# %% [markdown]
# ### Read 2018 population data

# %%
dfp = pd.read_csv('../files/census/co-est2018-alldata.csv', encoding='ISO-8859-1')

# %%
dfp['FIPS'] = dfp.STATE.map(lambda x: '{:02d}'.format(x)) + dfp.COUNTY.map(lambda x: 
                                                                        '{:03d}'.format(x))

# %%
keep_columns = ['RNETMIG2018', 'RDOMESTICMIG2018', 'RINTERNATIONALMIG2018',
               'RNATURALINC2018', 'RDEATH2018', 'RBIRTH2018',
               'REGION', 'DIVISION', 'FIPS']

# %%
divide_columns = ['GQESTIMATES2018', 'NPOPCHG_2018']

# %%
for col in divide_columns:
    dfp[col] = dfp[col] / dfp.POPESTIMATE2018

# %%
dfp = dfp[keep_columns + divide_columns]

# %%
df = dfc.set_index('FIPS').join(dfp.set_index('FIPS'))

# %% [markdown]
# ### Read 2018 employment and income data

# %%
dfe = pd.read_csv('../files/census/unemployment.csv', encoding='ISO-8859-1', header=7)

# %%
dfe_keep = ['FIPStxt', 'Civilian_labor_force_2018', 'Employed_2018', 'Unemployed_2018', 
            'Median_Household_Income_2018', 'Rural_urban_continuum_code_2013',
           'Urban_influence_code_2013', 'Metro_2013']

# %%
dfe = dfe[dfe_keep]

# %%
with_commas = ['Civilian_labor_force_2018', 'Employed_2018', 'Unemployed_2018', 
            'Median_Household_Income_2018']

# %%
for col in with_commas:
    dfe[col] = dfe[col].str.replace(',', '').fillna(0).astype(int).replace(0, np.nan)

# %% [markdown]
# #### Some counties in Alaska have missing values

# %%
dfe['Employed_2018'].sort_values()[-5:]
# Out:
# 194     18460725.0
# 0      155102319.0
# 92             NaN
# 95             NaN
# 99             NaN
# Name: Employed_2018, dtype: float64

# %%
dfe.loc[dfe['Employed_2018'].isnull()]
# Out:
#     FIPStxt  Civilian_labor_force_2018  Employed_2018  Unemployed_2018  \
# 92     2201                        NaN            NaN              NaN
# 95     2232                        NaN            NaN              NaN
# 99     2280                        NaN            NaN              NaN
#
#     Median_Household_Income_2018  Rural_urban_continuum_code_2013  \
# 92                           NaN                              NaN
# 95                           NaN                              NaN
# 99                           NaN                              NaN
#
#     Urban_influence_code_2013  Metro_2013
# 92                        NaN         0.0
# 95                        NaN         0.0
# 99                        NaN         0.0

# %%
dfe['FIPStxt'] = dfe.FIPStxt.map(lambda x: '{:05d}'.format(x))

# %%
df_temp = df.join(dfe.set_index('FIPStxt'))

# %%
new_divide = ['Civilian_labor_force_2018', 'Employed_2018', 'Unemployed_2018']

# %%
for col in new_divide:
    df_temp[col] = df_temp[col] / df_temp.TOT_POP

# %%
df = df_temp

# %%
# SET EMPLOYMENT AND UNEMPLOYMENT RATES TO BE PERCENT OF LABOR FORCE
df['Employed_2018'] = df['Employed_2018'] / df['Civilian_labor_force_2018']
df['Unemployed_2018'] = df['Unemployed_2018'] / df['Civilian_labor_force_2018']

# %% [markdown]
# ### Read 2018 education data

# %%
dfd = pd.read_csv('../files/census/education.csv', encoding='ISO-8859-1', header=4)

# %%
dfd_keep = ['FIPS Code', 'Percent of adults with less than a high school diploma, 2014-18',
           'Percent of adults with a high school diploma only, 2014-18',
           'Percent of adults completing some college or associate\'s degree, 2014-18',
           'Percent of adults with a bachelor\'s degree or higher, 2014-18']

# %%
dfd = dfd[dfd_keep]

# %%
dfd['FIPS Code'] = dfd['FIPS Code'].map(lambda x: '{:05d}'.format(x))

# %%
df = df.join(dfd.set_index('FIPS Code'))

# %% [markdown]
# ### Read land area data

# %%
dfl = pd.read_csv('../files/land.csv')

# %%
dfl.fips = dfl.fips.map(lambda x: '{:05d}'.format(x))

# %%
dfl = dfl.drop('POP060210', axis=1)

# %%
dfl.rename(columns={'LND110210':'LAND_AREA'}, inplace=True)

# %%
df = df.join(dfl.set_index('fips'))

# %%
df['DENSITY'] = df.TOT_POP / df.LAND_AREA

# %%
df
# Out:
#        STATE  COUNTY   STNAME            CTYNAME  TOT_POP  TOT_MALE  \
# FIPS
# 01001      1       1  Alabama     Autauga County    55601  0.000009
# 56039               0.533278                   0.509664
# 56041               0.502576                   0.548011
# 56043               0.500000                   0.538879
# 56045               0.533019                   0.543662
#
#        TOT_MALE_twenty_twentyfour  TOT_MALE_twentyfive_twentynine  \
# FIPS
# 01001                    0.513394                        0.493927
# 01003                    0.507022                        0.492743
# 01005                    0.591712                        0.630846
# 01007                    0.588642                        0.575898
# 01009                    0.528634                        0.502525
# ...                           ...                             ...
# 56037                    0.522359                        0.515537
# 56039                    0.431354                        0.535204
# 56041                    0.501502                        0.485269
# 56043                    0.502841                        0.504132
# 56045                    0.615385                        0.571816
#
#        TOT_MALE_thirty_thirtyfour  TOT_MALE_thirtyfive_thirtynine  \
# FIPS
# 01001                    0.479341                        0.487045
# 01003                    0.492743                        0.480237
# 01005                    0.594012                        0.602874
# 01007                    0.599625                        0.603175
# 01009                    0.500593                        0.505122
# ...                           ...                             ...
# 56037                    0.508618                        0.516243
# 56039                    0.523176                        0.544794
# 56041                    0.496779                        0.506164
# 56043                    0.552885                        0.476386
# 56045                    0.544186                        0.544118
#
#        TOT_MALE_forty_fortyfour  TOT_MALE_fortyfive_fortynine  \
# FIPS
# 01001                  0.474834                      0.482098
# 01003                  0.486216                      0.486688
# 01005                  0.597931                      0.572044
# 01007                  0.552778                      0.554443
# 01009                  0.489446                      0.502168
# ...                         ...                           ...
# 56037                  0.524665                      0.520833
# 56039                  0.552995                      0.547125
# 56041                  0.500795                      0.509717
# 56043                  0.500000                      0.528261
# 56045                  0.561644                      0.579946
#
#        TOT_MALE_fifty_fiftyfour  TOT_MALE_fiftyfive_fiftynine  \
# FIPS
# 01001                  0.484125                      0.498090
# 01003                  0.478655                      0.471037
# 01005                  0.528384                      0.493134
# 01007                  0.535737                      0.522164
# 01009                  0.493457                      0.515328
# ...                         ...                           ...
# 56037                  0.521411                      0.523098
# 56039                  0.491216                      0.494352
# 56041                  0.511236                      0.505857
# 56043                  0.523166                      0.490300
# 56045                  0.526196                      0.535649
#
#        TOT_MALE_sixty_sixtyfour  TOT_MALE_sixtyfive_sixtynine  \
# FIPS
# 01001                  0.462156                      0.474314
# 01003                  0.466454                      0.464148
# 01005                  0.487630                      0.455195
# 01007                  0.492296                      0.487310
# 01009                  0.484659                      0.476539
# ...                         ...                           ...
# 56037                  0.537552                      0.513304
# 56039                  0.512638                      0.537538
# 56041                  0.504178                      0.519678
# 56043                  0.514143                      0.518375
# 56045                  0.513393                      0.564482
#
#        TOT_MALE_seventy_seventyfour  TOT_MALE_seventyfive_seventynine  \
# FIPS
# 01001                      0.440935                          0.416331
# 01003                      0.479031                          0.466155
# 01005                      0.454749                          0.442117
# 01007                      0.458669                          0.441860
# 01009                      0.448835                          0.456345
# ...                             ...                               ...
# 56037                      0.504029                          0.507803
# 56039                      0.508647                          0.501706
# 56041                      0.519582                          0.503212
# 56043                      0.485714                          0.545171
# 56045                      0.500000                          0.464286
#
#        TOT_MALE_eighty_eightyfour  TOT_MALE_eightyfive_older  \
# FIPS
# 01001                    0.426072                   0.377727
# 01003                    0.470774                   0.407760
# 01005                    0.401042                   0.313559
# 01007                    0.390995                   0.297521
# 01009                    0.451266                   0.359496
# ...                           ...                        ...
# 56037                    0.447699                   0.339703
# 56039                    0.463855                   0.406154
# 56041                    0.452381                   0.349020
# 56043                    0.400000                   0.400826
# 56045                    0.448980                   0.345000
#
#        TOT_POP_zero_four  TOT_POP_five_nine  TOT_POP_ten_fourteen  \
# FIPS
# 01001           0.060503           0.061564              0.069819
# 01003           0.054834           0.058719              0.064127
# 01005           0.051606           0.058197              0.060649
# 01007           0.057366           0.052277              0.059196
# 01009           0.059820           0.062846              0.067462
# ...                  ...                ...                   ...
# 56037           0.068500           0.073285              0.076909
# 56039           0.049045           0.054244              0.052077
# 56041           0.073206           0.080546              0.086063
# 56043           0.051490           0.057324              0.071021
# 56045           0.051529           0.060428              0.060858
#
#        TOT_POP_fifteen_nineteen  TOT_POP_twenty_twentyfour  \
# FIPS
# 01001                  0.067535                   0.057067
# 01003                  0.059315                   0.050949
# 01005                  0.058318                   0.059162
# 01007                  0.056696                   0.058170
# 01009                  0.063416                   0.054945
# ...                         ...                        ...
# 56037                  0.070033                   0.058698
# 56039                  0.042589                   0.046705
# 56041                  0.071826                   0.049214
# 56043                  0.070133                   0.044642
# 56045                  0.050954                   0.044783
#
#        TOT_POP_twentyfive_twentynine  TOT_POP_thirty_thirtyfour  \
# FIPS
# 01001                       0.066635                   0.062247
# 01003                       0.057201                   0.055302
# 01005                       0.072184                   0.067119
# 01007                       0.077054                   0.071473
# 01009                       0.061618                   0.058264
# ...                              ...                        ...
# 56037                       0.065782                   0.074121
# 56039                       0.081842                   0.087864
# 56041                       0.056850                   0.061185
# 56043                       0.046037                   0.052758
# 56045                       0.052964                   0.061720
#
#        TOT_POP_thirtyfive_thirtynine  TOT_POP_forty_fortyfour  \
# FIPS
# 01001                       0.065251                 0.065035
# 01003                       0.060343                 0.059063
# 01005                       0.061533                 0.058277
# 01007                       0.067500                 0.064286
# 01009                       0.060754                 0.061428
# ...                              ...                      ...
# 56037                       0.078651                 0.065922
# 56039                       0.089468                 0.075213
# 56041                       0.071925                 0.061973
# 56043                       0.061763                 0.055802
# 56045                       0.068322                 0.052390
#
#        TOT_POP_fortyfive_fortynine  TOT_POP_fifty_fiftyfour  \
# FIPS
# 01001                     0.071330                 0.068542
# 01003                     0.066328                 0.065324
# 01005                     0.065271                 0.064427
# 01007                     0.071339                 0.070580
# 01009                     0.067790                 0.067376
# ...                            ...                      ...
# 56037                     0.057978                 0.055330
# 56039                     0.073090                 0.061652
# 56041                     0.055766                 0.052613
# 56043                     0.058339                 0.065694
# 56045                     0.052964                 0.063011
#
#        TOT_POP_fiftyfive_fiftynine  TOT_POP_sixty_sixtyfour  \
# FIPS
# 01001                     0.070628                 0.058218
# 01003                     0.072213                 0.071851
# 01005                     0.067320                 0.061734
# 01007                     0.068482                 0.060848
# 01009                     0.068240                 0.063676
# ...                            ...                      ...
# 56037                     0.066874                 0.066804
# FIPS
# 01001       0.964308         0.035692                       59338.0
# 01003       0.964046         0.035954                       57588.0
# 01005       0.949251         0.050749                       34382.0
# 01007       0.960837         0.039163                       46064.0
# 01009       0.965376         0.034624                       50412.0
# ...              ...              ...                           ...
# 56037       0.959596         0.040404                       73315.0
# 56039       0.971048         0.028952                       99087.0
# 56041       0.958130         0.041870                       63401.0
# 56043       0.959093         0.040907                       55190.0
# 56045       0.966552         0.033448                       54319.0
#
#        Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# FIPS
# 01001                              2.0                        2.0         1.0
# 01003                              3.0                        2.0         1.0
# 01005                              6.0                        6.0         0.0
# 01007                              1.0                        1.0         1.0
# 01009                              1.0                        1.0         1.0
# ...                                ...                        ...         ...
# 56037                              5.0                        8.0         0.0
# 56039                              7.0                        8.0         0.0
# 56041                              7.0                        8.0         0.0
# 56043                              7.0                       11.0         0.0
# 56045                              7.0                        9.0         0.0
#
#        Percent of adults with less than a high school diploma, 2014-18  \
# FIPS
# 01001                                               11.3
# 01003                                                9.7
# 01005                                               27.0
# 01007                                               16.8
# 01009                                               19.8
# ...                                                  ...
# 56037                                                9.0
# 56039                                                5.6
# 56041                                                7.2
# 56043                                               10.4
# 56045                                                7.8
#
#        Percent of adults with a high school diploma only, 2014-18  \
# FIPS
# 01001                                               32.6
# 01003                                               27.6
# 01005                                               35.7
# 01007                                               47.3
# 01009                                               34.0
# ...                                                  ...
# 56037                                               33.3
# 56039                                               13.2
# 56041                                               40.1
# 56043                                               30.3
# 56045                                               35.8
#
#        Percent of adults completing some college or associate's degree, 2014-18  \
# FIPS
# 01001                                               28.4
# 01003                                               31.3
# 01005                                               25.1
# 01007                                               24.4
# 01009                                               33.5
# ...                                                  ...
# 56037                                               35.7
# 56039                                               23.8
# 56041                                               37.2
# 56043                                               37.7
# 56045                                               37.3
#
#        Percent of adults with a bachelor's degree or higher, 2014-18  \
# FIPS
# 01001                                               27.7
# 01003                                               31.3
# 01005                                               12.2
# 01007                                               11.5
# 01009                                               12.6
# ...                                                  ...
# 56037                                               22.0
# 56039                                               57.4
# 56041                                               15.4
# 56043                                               21.5
# 56045                                               19.2
#
#        LAND_AREA     DENSITY
# FIPS
# 01001     594.44   93.535092
# 01003    1589.78  137.139730
# 01005     884.88   28.117937
# 01007     622.58   35.979312
# 01009     644.78   89.705016
# ...          ...         ...
# 56037   10426.65    4.128939
# 56039    3995.38    5.776922
# 56041    2081.26    9.753226
# 56043    2238.55    3.522369
# 56045    2398.09    2.905229
#
# [3142 rows x 101 columns]

# %%
dfdc = pd.read_csv('../files/census/dc.csv')

# %%
dfdc.county = dfdc.county.map(lambda x: x[6:])

# %%
df = df.join(dfdc[['county', 'med_age']].set_index('county'))

# %%
df = df.loc[~df['Median_Household_Income_2018'].isnull()]

# %% [markdown]
# ### Save census data to disk

# %%
df.to_csv('../files/modeling_data/census_data_age_gend.csv')

# %% [markdown]
# ### Look at hypothesis from *Logic of Life*

# %%
import scipy.stats as st

# %%
dh = df.copy()

# %%
dh['young_wr'] = ((1 - dh.TOT_MALE_twenty_twentyfour) + \
                 (1 - dh.TOT_MALE_twentyfive_twentynine)) / 2

# %%
low_pop = dh.DENSITY.quantile(0.2)

# %%
dh['young_wa'] = (((1 - dh.TOT_MALE_twenty_twentyfour) * dh.TOT_POP_twenty_twentyfour) + \
    (((1 - dh.TOT_MALE_twentyfive_twentynine) * dh.TOT_POP_twentyfive_twentynine))) * dh.TOT_POP

# %%
dh['young_w'] = (dh.young_wa.rank() + dh.young_wr.rank()) / 2

# %%
dh = dh.loc[dh.DENSITY > low_pop]

# %%
x = dh['Median_Household_Income_2018']
y = dh.young_w

# %%
st.pearsonr(x, y)
# Out:
# (0.2946146016890563, 1.7480273659554066e-51)

# %%
plt.scatter(x, y, alpha=0.2, s=10)

# %%
dh.sort_values(by='young_w', ascending=False)[['STNAME', 'CTYNAME', 'young_wa', 'young_wr',
                                              'Median_Household_Income_2018']][:50]
# Out:
#                      STNAME               CTYNAME  young_wa  young_wr  \
# FIPS
# 36061              New York       New York County  160265.0  0.536693
# 11001  District of Columbia  District of Columbia   73576.0  0.542647
# 47037             Tennessee       Davidson County   65249.0  0.525467
# 36047              New York          Kings County  208827.0  0.518900
# 13089               Georgia         DeKalb County   58586.0  0.522847
# 24510              Maryland        Baltimore city   52911.0  0.521589
# 42101          Pennsylvania   Philadelphia County  140657.0  0.513973
# 25025         Massachusetts        Suffolk County   92931.0  0.514296
# 18097               Indiana         Marion County   78495.0  0.514814
# 37081        North Carolina       Guilford County   40374.0  0.520688
# 22071             Louisiana        Orleans Parish   30613.0  0.524849
# 12073               Florida           Leon County   36899.0  0.517670
# 51760              Virginia         Richmond city   24887.0  0.528350
# 01073               Alabama      Jefferson County   47266.0  0.514221
# 37119        North Carolina    Mecklenburg County   85606.0  0.509933
# 37147        North Carolina           Pitt County   19643.0  0.528665
# 37067        North Carolina        Forsyth County   26434.0  0.519045
# 13063               Georgia        Clayton County   23507.0  0.519945
# 47157             Tennessee         Shelby County   70193.0  0.509513
# 28049           Mississippi          Hinds County   19520.0  0.524083
# 25015         Massachusetts      Hampshire County   17895.0  0.525018
# 51510              Virginia       Alexandria city   12712.0  0.548382
# 39035                  Ohio       Cuyahoga County   87593.0  0.507258
# 37135        North Carolina         Orange County   14856.0  0.529612
# 29510              Missouri        St. Louis city   27355.0  0.513743
# 37063        North Carolina         Durham County   26283.0  0.513771
# 25021         Massachusetts        Norfolk County   44995.0  0.509530
# 41051                Oregon      Multnomah County   62246.0  0.507957
# 55079             Wisconsin      Milwaukee County   74075.0  0.507095
# 36081              New York         Queens County  160447.0  0.505780
# 39049                  Ohio       Franklin County  110224.0  0.505856
# 01097               Alabama         Mobile County   29344.0  0.511018
# 36005              New York          Bronx County  115058.0  0.505111
# 06113            California           Yolo County   24501.0  0.512775
# 24005              Maryland      Baltimore County   54450.0  0.507227
# 29095              Missouri        Jackson County   50687.0  0.507831
# 29019              Missouri          Boone County   21185.0  0.513463
# 13021               Georgia           Bibb County   11870.0  0.528812
# 26163              Michigan          Wayne County  126332.0  0.504453
# 13059               Georgia         Clarke County   18432.0  0.514369
# 51041              Virginia   Chesterfield County   21264.0  0.512191
# 45091        South Carolina           York County   16770.0  0.515958
# 37001        North Carolina       Alamance County   11390.0  0.525991
# 06039            California         Madera County   11667.0  0.522918
# 29189              Missouri      St. Louis County   63700.0  0.504679
# 17031              Illinois           Cook County  387006.0  0.503015
# 27123             Minnesota         Ramsey County   43859.0  0.505811
# 22051             Louisiana      Jefferson Parish   28514.0  0.508496
# 37129        North Carolina    New Hanover County   19528.0  0.510979
# 48121                 Texas         Denton County   59812.0  0.504381
#
#        Median_Household_Income_2018
# FIPS
# 36061                       84610.0
# 11001                       82533.0
# 47037                       60799.0
# 36047                       60862.0
# 13089                       63477.0
# 24510                       50501.0
# 42101                       46149.0
# 25025                       68743.0
# 18097                       48409.0
# 37081                       52166.0
# 22071                       38855.0
# 12073                       51046.0
# 51760                       48747.0
# 01073                       55013.0
# 37119                       64509.0
# 37147                       43303.0
# 37067                       50112.0
# 13063                       46059.0
# 47157                       47924.0
# 28049                       44776.0
# 25015                       74456.0
# 51510                       99425.0
# 39035                       50006.0
# 37135                       71920.0
# 29510                       43263.0
# 37063                       59329.0
# 25021                      100184.0
# 41051                       70756.0
# 55079                       49771.0
# 36081                       68432.0
# 39049                       60383.0
# 01097                       43598.0
# 36005                       38566.0
# 06113                       67804.0
# 24005                       75836.0
# 29095                       55864.0
# 29019                       55136.0
# 13021                       41390.0
# 26163                       46440.0
# 13059                       42112.0
# 51041                       80734.0
# 45091                       64904.0
# 37001                       50480.0
# 06039                       53632.0
# 29189                       66992.0
# 17031                       63347.0
# 27123                       62937.0
# 22051                       50871.0
# 37129                       53419.0
# 48121                       88384.0

# %%
dh.sort_values(by='young_wr', ascending=False)[['STNAME', 'CTYNAME', 'young_wa', 'young_wr']][:50]
# Out:
#                      STNAME               CTYNAME  young_wa  young_wr
# FIPS
# 13235               Georgia        Pulaski County     793.0  0.603757
# 29117              Missouri     Livingston County    1159.0  0.594765
# 51790              Virginia         Staunton city    1840.0  0.583430
# 29007              Missouri        Audrain County    1878.0  0.582678
# 51065              Virginia       Fluvanna County    1700.0  0.581046
# 18121               Indiana          Parke County    1207.0  0.572165
# 54089         West Virginia        Summers County     754.0  0.567318
# 51630              Virginia   Fredericksburg city    3759.0  0.559500
# 05041              Arkansas          Desha County     692.0  0.550241
# 51510              Virginia       Alexandria city   12712.0  0.548382
# 45047        South Carolina      Greenwood County    5098.0  0.544464
# 11001  District of Columbia  District of Columbia   73576.0  0.542647
# 39159                  Ohio          Union County    3812.0  0.541093
# 28143           Mississippi         Tunica County     717.0  0.541036
# 51830              Virginia     Williamsburg city    2284.0  0.539551
# 51730              Virginia       Petersburg city    2766.0  0.539459
# 01087               Alabama          Macon County    1869.0  0.537953
# 36061              New York       New York County  160265.0  0.536693
# 28021           Mississippi      Claiborne County     930.0  0.534901
# 13095               Georgia      Dougherty County    7850.0  0.534840
# 01047               Alabama         Dallas County    2541.0  0.534573
# 48051                 Texas       Burleson County    1079.0  0.534492
# 45041        South Carolina       Florence County    9617.0  0.534159
# 13137               Georgia      Habersham County    3186.0  0.533861
# 05107              Arkansas       Phillips County    1163.0  0.532991
# 19185                  Iowa          Wayne County     344.0  0.532542
# 51820              Virginia       Waynesboro city    1552.0  0.532372
# 28035           Mississippi        Forrest County    7734.0  0.532047
# 18077               Indiana      Jefferson County    2304.0  0.531124
# 01119               Alabama         Sumter County    1435.0  0.530015
# 29205              Missouri         Shelby County     315.0  0.529900
# 37135        North Carolina         Orange County   14856.0  0.529612
# 31143              Nebraska           Polk County     268.0  0.529207
# 13021               Georgia           Bibb County   11870.0  0.528812
# 37147        North Carolina           Pitt County   19643.0  0.528665
# 27161             Minnesota         Waseca County    1133.0  0.528604
# 51760              Virginia         Richmond city   24887.0  0.528350
# 51620              Virginia         Franklin city     500.0  0.528143
# 24045              Maryland       Wicomico County    8909.0  0.527968
# 21239              Kentucky       Woodford County    1517.0  0.527860
# 28161           Mississippi      Yalobusha County     791.0  0.526784
# 37065        North Carolina      Edgecombe County    3379.0  0.526596
# 51595              Virginia          Emporia city     344.0  0.526580
# 28027           Mississippi        Coahoma County    1653.0  0.526445
# 13043               Georgia        Candler County     682.0  0.526413
# 47113             Tennessee        Madison County    7102.0  0.526349
# 37001        North Carolina       Alamance County   11390.0  0.525991
# 36123              New York          Yates County    1759.0  0.525637
# 47037             Tennessee       Davidson County   65249.0  0.525467
# 13275               Georgia         Thomas County    2743.0  0.525295

# %%
dh.loc[dh.CTYNAME == 'Los Angeles County']
# Out:
#        STATE  COUNTY      STNAME             CTYNAME   TOT_POP      TOT_MALE  \
# FIPS
# 06037      6      37  California  Los Angeles County  10105518  4.878400e-08
#
#        TOT_FEMALE        WA      BA        IA        AA        NA       TOM  \
# FIPS
# 06037    0.507012  0.707677  0.0897  0.014374  0.153569  0.003681  0.030999
#
#            WAC       BAC       IAC       AAC       NAC        NH     NHWA  \
# FIPS
# 06037  0.73452  0.099737  0.022892  0.170292  0.006702  0.513604  0.26118
#
#            NHBA      NHIA      NHAA      NHNA     NHTOM    NHWAC     NHBAC  \
# FIPS
# 06037  0.079645  0.001875  0.147495  0.002286  0.021123  0.27933  0.086505
#
#           NHIAC     NHAAC     NHNAC         H       HWA       HBA       HIA  \
# FIPS
# 06037  0.006145  0.160171  0.004425  0.486396  0.446497  0.010055  0.012499
#
#             HAA       HNA      HTOM     HWAC      HBAC      HIAC      HAAC  \
# FIPS
# 06037  0.006074  0.001395  0.009876  0.45519  0.013232  0.016748  0.010121
#
#            HNAC  TOT_MALE_zero_four  TOT_MALE_five_nine  \
# FIPS
# 06037  0.002278            0.513093            0.511614
#
#        TOT_MALE_ten_fourteen  TOT_MALE_fifteen_nineteen  \
# FIPS
# 06037               0.511443                   0.508357
#
#        TOT_MALE_twenty_twentyfour  TOT_MALE_twentyfive_twentynine  \
# FIPS
# 06037                    0.503493                        0.509047
#
#        TOT_MALE_thirty_thirtyfour  TOT_MALE_thirtyfive_thirtynine  \
# FIPS
# 06037                    0.512385                         0.50565
#
#        TOT_MALE_forty_fortyfour  TOT_MALE_fortyfive_fortynine  \
# FIPS
# 06037                  0.496827                      0.495081
#
#        TOT_MALE_fifty_fiftyfour  TOT_MALE_fiftyfive_fiftynine  \
# FIPS
# 06037                   0.49461                      0.487829
#
#        TOT_MALE_sixty_sixtyfour  TOT_MALE_sixtyfive_sixtynine  \
# FIPS
# 06037                  0.476132                      0.461863
#
#        TOT_MALE_seventy_seventyfour  TOT_MALE_seventyfive_seventynine  \
# FIPS
# 06037                      0.449324                           0.43219
#
#        TOT_MALE_eighty_eightyfour  TOT_MALE_eightyfive_older  \
# FIPS
# 06037                    0.411218                   0.359863
#
#        TOT_POP_zero_four  TOT_POP_five_nine  TOT_POP_ten_fourteen  \
# FIPS
# 06037           0.059725           0.059838              0.060384
#
#        TOT_POP_fifteen_nineteen  TOT_POP_twenty_twentyfour  \
# FIPS
# 06037                  0.062236                   0.069363
#
#        TOT_POP_twentyfive_twentynine  TOT_POP_thirty_thirtyfour  \
# FIPS
# 06037                       0.084718                   0.077573
#
#        TOT_POP_thirtyfive_thirtynine  TOT_POP_forty_fortyfour  \
# FIPS
# 06037                       0.071043                 0.065627
#
#        TOT_POP_fortyfive_fortynine  TOT_POP_fifty_fiftyfour  \
# FIPS
# 06037                     0.067971                 0.065478
#
#        TOT_POP_fiftyfive_fiftynine  TOT_POP_sixty_sixtyfour  \
# FIPS
# 06037                     0.063759                 0.056125
#
#        TOT_POP_sixtyfive_sixtynine  TOT_POP_seventy_seventyfour  \
# FIPS
# 06037                     0.044248                     0.033395
#
#        TOT_POP_seventyfive_seventynine  TOT_POP_eighty_eightyfour  \
# FIPS
# 06037                         0.023261                   0.016309
#
#        TOT_POP_eightyfive_older  RNETMIG2018  RDOMESTICMIG2018  \
# FIPS
# 06037                  0.018946    -6.300744         -9.751449
#
#        RINTERNATIONALMIG2018  RNATURALINC2018  RDEATH2018  RBIRTH2018  REGION  \
# FIPS
# 06037               3.450704         4.978868    6.814286   11.793153       4
#
#        DIVISION  GQESTIMATES2018  NPOPCHG_2018  Civilian_labor_force_2018  \
# FIPS
# 06037         9         0.017647      -0.00131                    0.50423
#
#        Employed_2018  Unemployed_2018  Median_Household_Income_2018  \
# FIPS
# 06037       0.953843         0.046157                       67986.0
#
#        Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# FIPS
# 06037                              1.0                        1.0         1.0
#
#        Percent of adults with less than a high school diploma, 2014-18  \
# FIPS
# 06037                                               21.3
#
#        Percent of adults with a high school diploma only, 2014-18  \
# FIPS
# 06037                                               20.7
#
#        Percent of adults completing some college or associate's degree, 2014-18  \
# FIPS
# 06037                                               26.2
#
#        Percent of adults with a bachelor's degree or higher, 2014-18  \
# FIPS
# 06037                                               31.8
#
#        LAND_AREA      DENSITY  med_age  young_wr  young_wa  young_w
# FIPS
# 06037    4057.88  2490.344219     36.0   0.49373  768343.0   2641.0
